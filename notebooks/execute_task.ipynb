# %%
from src.dependencies.constant import TRAIN_PATH, TEST_PATH, CORPUS_PATH, CORPUS_JSON_PATH, TEST_QUERIES_JSON_PATH
from src.dependencies.spark import SparkIRSystem
from src.preprocessing.mining_job import load_data

# %%
spark = SparkIRSystem()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/08 17:25:44 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
train_data = load_data(spark, TRAIN_PATH)

# %%
test_data = load_data(spark, TEST_PATH)

# %%
# corpus_data = load_data(spark, CORPUS_PATH)

# %% [markdown]
# # Change corpus file to JSON

# %%
# from src.preprocessing.build_documents import build_documents_json
#
# build_documents_json(CORPUS_JSON_PATH, corpus_data)

# %% [markdown]
# # Build test queries json file from test.parquet

# %%
from src.preprocessing.build_documents import build_test_queries
from src.dependencies.constant import TEST_QUERIES_JSON_PATH
build_test_queries(TEST_QUERIES_JSON_PATH, test_data)
